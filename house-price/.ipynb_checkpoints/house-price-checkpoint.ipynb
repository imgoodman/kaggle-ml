# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train_df=pd.read_csv("./input/train.csv")
test_df=pd.read_csv("./input/test.csv")
combine=[train_df, test_df]

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
help(pd.DataFrame.describe)
# Out:
# Help on function describe in module pandas.core.generic:
#
# describe(self, percentiles=None, include=None, exclude=None)
#     Generates descriptive statistics that summarize the central tendency,
#     dispersion and shape of a dataset's distribution, excluding
#     ``NaN`` values.
#
#     Analyzes both numeric and object series, as well
#     as ``DataFrame`` column sets of mixed data types. The output
#     will vary depending on what is provided. Refer to the notes
#     below for more detail.
#
#     Parameters
#     ----------
#     percentiles : list-like of numbers, optional
#         The percentiles to include in the output. All should
#         fall between 0 and 1. The default is
#         ``[.25, .5, .75]``, which returns the 25th, 50th, and
#         75th percentiles.
#     include : 'all', list-like of dtypes or None (default), optional
#         A white list of data types to include in the result. Ignored
#         for ``Series``. Here are the options:
#
# ...

# %%
train_df.describe(include=[np.number, np.object])
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
train_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %%
train_df.tail(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
# Id               1459 non-null int64
# MSSubClass       1459 non-null int64
# MSZoning         1455 non-null object
# LotFrontage      1232 non-null float64
# LotArea          1459 non-null int64
# Street           1459 non-null object
# Alley            107 non-null object
# LotShape         1459 non-null object
# LandContour      1459 non-null object
# Utilities        1457 non-null object
# LotConfig        1459 non-null object
# LandSlope        1459 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# HouseStyle       1459 non-null object
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# RoofStyle        1459 non-null object
# ...

# %%
test_df.describe(include=[np.number, np.object])
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage       LotArea Street  \
# count   1459.000000  1459.000000     1455  1232.000000   1459.000000   1459
# unique          NaN          NaN        5          NaN           NaN      2
# top             NaN          NaN       RL          NaN           NaN   Pave
# freq            NaN          NaN     1114          NaN           NaN   1453
# mean    2190.000000    57.378341      NaN    68.580357   9819.161069    NaN
# std      421.321334    42.746880      NaN    22.376841   4955.517327    NaN
# min     1461.000000    20.000000      NaN    21.000000   1470.000000    NaN
# 25%     1825.500000    20.000000      NaN    58.000000   7391.000000    NaN
# 50%     2190.000000    50.000000      NaN    67.000000   9399.000000    NaN
# 75%     2554.500000    70.000000      NaN    80.000000  11517.500000    NaN
# max     2919.000000   190.000000      NaN   200.000000  56600.000000    NaN
#
# ...

# %%
test_df.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# ...

# %%
test_df.tail(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1449  2910         180       RM         21.0     1470   Pave   NaN      Reg
# 1450  2911         160       RM         21.0     1484   Pave   NaN      Reg
# 1451  2912          20       RL         80.0    13384   Pave   NaN      Reg
# 1452  2913         160       RM         21.0     1533   Pave   NaN      Reg
# 1453  2914         160       RM         21.0     1526   Pave   NaN      Reg
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %% [markdown]
# # 训练数据共1460条，每条数据有81个特征
# # 测试数据共1459条，每条数据有80个特征
# ## 数值型特征38个，文本型特征43个

# %% [markdown]
# ## 01-分析MSSubClass特征
# the building class，数字型特征，训练数据中没有空值，查看该特征与售价之间的关系

# %%
g_mssubclass=sns.FacetGrid(train_df, row="MSSubClass")
g_mssubclass.map(plt.hist, "SalePrice", bins=20)

# %%
train_df[["MSSubClass", "SalePrice"]].groupby(["MSSubClass"], as_index=False).mean().sort_values(by="SalePrice", ascending=False)
# Out:
#     MSSubClass      SalePrice
# 5           60  239948.501672
# 11         120  200779.080460
# 7           75  192437.500000
# 0           20  185224.811567
# 8           80  169736.551724
# 6           70  166772.416667
# 2           40  156125.000000
# 9           85  147810.000000
# 4           50  143302.972222
# 12         160  138647.380952
# 10          90  133541.076923
# 14         190  129613.333333
# 3           45  108591.666667
# 13         180  102300.000000
# 1           30   95829.724638

# %%
train_df["MSSubClass"].value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
test_df["MSSubClass"].value_counts()
# Out:
# 20     543
# 60     276
# 50     143
# 120     95
# 30      70
# 70      68
# 160     65
# 80      60
# 90      57
# 190     31
# 85      28
# 180      7
# 75       7
# 45       6
# 40       2
# 150      1
# Name: MSSubClass, dtype: int64

# %% [markdown]
# ## MSSubClass共有15个不同的取值，最小20，最大190
# 1. MSSubClass取值最小20的时候，售价为第四高
# 2. 取值最大190的时候，售价反而倒数第四高
# 3. 售价最高的是，MSSubClass=60
# 4. 售价最低的是，MSSubClass=30
# 5. 出现次数最多的是，MSSubClass=20（在训练数据和测试数据相同）
# 6. 出现次数最少的是,MSSubClass=40
#
# ### 结论
# 该特征将作为建模特征
# ### 不确定
# 1. 由于它的取值只有15个，是否需要把他们转化为顺序值呢？

# %% [markdown]
# ## 02-分析MSZoning
# the general zoning classification，取值是文本类型，训练数据中不包含空值，测试数据中有4个空值，查看该特征与售价之间的关系

# %%
g_mszoning=sns.FacetGrid(train_df, row="MSZoning")
g_mszoning.map(plt.hist, "SalePrice")

# %%
train_df[["MSZoning", "SalePrice"]].groupby(["MSZoning"], as_index=False).mean().sort_values(by="SalePrice", ascending=False)
# Out:
#   MSZoning      SalePrice
# 1       FV  214014.061538
# 3       RL  191004.994787
# 2       RH  131558.375000
# 4       RM  126316.830275
# 0  C (all)   74528.000000

# %%
train_df["MSZoning"].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
test_df["MSZoning"].value_counts()
# Out:
# RL         1114
# RM          242
# FV           74
# C (all)      15
# RH           10
# Name: MSZoning, dtype: int64

# %%
test_df[test_df["MSZoning"].isnull().values==True]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 455   1916          30      NaN        109.0    21780   Grvl   NaN      Reg
# 756   2217          20      NaN         80.0    14584   Pave   NaN      Reg
# 790   2251          70      NaN          NaN    56600   Pave   NaN      IR1
# 1444  2905          20      NaN        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities      ...       ScreenPorch PoolArea PoolQC Fence  \
# 455          Lvl       NaN      ...                 0        0    NaN   NaN
# 756          Low    AllPub      ...                 0        0    NaN   NaN
# 790          Low    AllPub      ...                 0        0    NaN   NaN
# 1444         Lvl    AllPub      ...                 0        0    NaN   NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 455          NaN       0      3    2009     ConLD         Normal
# 756          NaN       0      2    2008        WD        Abnorml
# ...

# %% [markdown]
# ### 结论
# 1. 该特征包含5个取值
# 2. FV对应的售价最高
# 3. C对应的售价最低
# 4. 将该特征转化为顺序值。
# 5. RL出现的次数最多，占据了绝大多数
# 6. 将该特征转化为顺序值
#
# ### 不确定
# 1. 出现频率的差别太大，是否需要只分为两类：是否是RL呢？或者三类：RL,RM和其他
# 2. 针对测试数据中，4条数据的值是空，如何填充这4个缺失值呢？
# 3. 填充缺失值的可行方法是：由于RL出现的次数最多，可以认为缺失的4个值就是RL！

# %%
train_df["MSZoning"]=train_df["MSZoning"].map({"RL":0, "RM":1, "FV":2, "C (all)":3, "RH":4}).astype(int)

train_df.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60         0         65.0     8450   Pave   NaN      Reg
# 1   2          20         0         80.0     9600   Pave   NaN      Reg
# 2   3          60         0         68.0    11250   Pave   NaN      IR1
# 3   4          70         0         60.0     9550   Pave   NaN      IR1
# 4   5          60         0         84.0    14260   Pave   NaN      IR1
# 5   6          50         0         85.0    14115   Pave   NaN      IR1
# 6   7          20         0         75.0    10084   Pave   NaN      Reg
# 7   8          60         0          NaN    10382   Pave   NaN      IR1
# 8   9          50         1         51.0     6120   Pave   NaN      Reg
# 9  10         190         0         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %%
test_df["MSZoning"]=test_df["MSZoning"].fillna("RL")
test_df["MSZoning"]=test_df["MSZoning"].map({"RL":0, "RM":1, "FV":2, "C (all)":3, "RH":4}).astype(int)
test_df.head(10)
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20         4         80.0    11622   Pave   NaN      Reg
# 1  1462          20         0         81.0    14267   Pave   NaN      IR1
# 2  1463          60         0         74.0    13830   Pave   NaN      IR1
# 3  1464          60         0         78.0     9978   Pave   NaN      IR1
# 4  1465         120         0         43.0     5005   Pave   NaN      IR1
# 5  1466          60         0         75.0    10000   Pave   NaN      IR1
# 6  1467          20         0          NaN     7980   Pave   NaN      IR1
# 7  1468          60         0         63.0     8402   Pave   NaN      IR1
# 8  1469          20         0         85.0    10176   Pave   NaN      Reg
# 9  1470          20         0         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# ...

# %% [markdown]
# ## 03-LotFrontage分析
#
# Linear feet of street connected to property
#
# 1. 训练数据：1201/1460
# 2. 测试数据：1232/1459
# 3. 训练和测试数据都有空值
# 4. 取值的变化幅度不大，最小21，最大313

# %%
train_df["LotFrontage"].describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
test_df["LotFrontage"].describe()
# Out:
# count    1232.000000
# mean       68.580357
# std        22.376841
# min        21.000000
# 25%        58.000000
# 50%        67.000000
# 75%        80.000000
# max       200.000000
# Name: LotFrontage, dtype: float64

# %%
train_df["LotFrontageBand"]=pd.cut(train_df["LotFrontage"].dropna(), 4)
train_df.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60         0         65.0     8450   Pave   NaN      Reg
# 1   2          20         0         80.0     9600   Pave   NaN      Reg
# 2   3          60         0         68.0    11250   Pave   NaN      IR1
# 3   4          70         0         60.0     9550   Pave   NaN      IR1
# 4   5          60         0         84.0    14260   Pave   NaN      IR1
# 5   6          50         0         85.0    14115   Pave   NaN      IR1
# 6   7          20         0         75.0    10084   Pave   NaN      Reg
# 7   8          60         0          NaN    10382   Pave   NaN      IR1
# 8   9          50         1         51.0     6120   Pave   NaN      Reg
# 9  10         190         0         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities       ...        PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub       ...           NaN    NaN         NaN       0
# ...

# %%
train_df = train_df.drop(["LotFrontageBand"],axis=1)
train_df.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60         0         65.0     8450   Pave   NaN      Reg
# 1   2          20         0         80.0     9600   Pave   NaN      Reg
# 2   3          60         0         68.0    11250   Pave   NaN      IR1
# 3   4          70         0         60.0     9550   Pave   NaN      IR1
# 4   5          60         0         84.0    14260   Pave   NaN      IR1
# 5   6          50         0         85.0    14115   Pave   NaN      IR1
# 6   7          20         0         75.0    10084   Pave   NaN      Reg
# 7   8          60         0          NaN    10382   Pave   NaN      IR1
# 8   9          50         1         51.0     6120   Pave   NaN      Reg
# 9  10         190         0         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# ## 04-分析LotArea
#
# Lot size in square feet

# %%
train_df["LotArea"].describe()
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
test_df["LotArea"].describe()
# Out:
# count     1459.000000
# mean      9819.161069
# std       4955.517327
# min       1470.000000
# 25%       7391.000000
# 50%       9399.000000
# 75%      11517.500000
# max      56600.000000
# Name: LotArea, dtype: float64

# %% [markdown]
# 可以看出：
# 1. 训练数据和测试数据都没有空值
# 2. 数据的变化幅度较大，最小1300，最大215245，只有零头不到
# 3. 因此，可以考虑该特征进行分段

# %%
train_df["LotAreaBand"]=pd.cut(train_df["LotArea"], 4)
train_df.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60         0         65.0     8450   Pave   NaN      Reg
# 1   2          20         0         80.0     9600   Pave   NaN      Reg
# 2   3          60         0         68.0    11250   Pave   NaN      IR1
# 3   4          70         0         60.0     9550   Pave   NaN      IR1
# 4   5          60         0         84.0    14260   Pave   NaN      IR1
# 5   6          50         0         85.0    14115   Pave   NaN      IR1
# 6   7          20         0         75.0    10084   Pave   NaN      Reg
# 7   8          60         0          NaN    10382   Pave   NaN      IR1
# 8   9          50         1         51.0     6120   Pave   NaN      Reg
# 9  10         190         0         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities          ...          PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub          ...             NaN    NaN         NaN
# ...

# %%
g_lotareaband=sns.FacetGrid(train_df, row="LotAreaBand")
g_lotareaband.map(plt.hist, "SalePrice", bins=50)

# %% [markdown]
# ## 05-分析Street
# Type of road access

# %%
train_df["Street"].describe()
# Out:
# count     1460
# unique       2
# top       Pave
# freq      1454
# Name: Street, dtype: object

# %%
test_df["Street"].describe()
# Out:
# count     1459
# unique       2
# top       Pave
# freq      1453
# Name: Street, dtype: object

# %% [markdown]
# 可以看出：
# 1. 训练和测试数据都没有空值
# 2. 取值都只有2个
# 3. Pave占绝大多数
# 4. 考虑转化为顺序值
# 5. 根据下图，认为，该特征与售价没有关系，可以考虑删除

# %%
train_df["Street"].value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
test_df["Street"].value_counts()
# Out:
# Pave    1453
# Grvl       6
# Name: Street, dtype: int64

# %%
g_street=sns.FacetGrid(train_df, col="Street")
g_street.map(plt.hist, "SalePrice")

# %%
train_df=train_df.drop(["Street"], axis=1)
train_df.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Alley LotShape LandContour  \
# 0   1          60         0         65.0     8450   NaN      Reg         Lvl
# 1   2          20         0         80.0     9600   NaN      Reg         Lvl
# 2   3          60         0         68.0    11250   NaN      IR1         Lvl
# 3   4          70         0         60.0     9550   NaN      IR1         Lvl
# 4   5          60         0         84.0    14260   NaN      IR1         Lvl
# 5   6          50         0         85.0    14115   NaN      IR1         Lvl
# 6   7          20         0         75.0    10084   NaN      Reg         Lvl
# 7   8          60         0          NaN    10382   NaN      IR1         Lvl
# 8   9          50         1         51.0     6120   NaN      Reg         Lvl
# 9  10         190         0         50.0     7420   NaN      Reg         Lvl
#
#   Utilities LotConfig          ...          PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
test_df=test_df.drop(["Street"], axis=1)

# %% [markdown]
# ## 06-分析Alley
#  Type of alley access

# %%
train_df["Alley"].describe()
# Out:
# count       91
# unique       2
# top       Grvl
# freq        50
# Name: Alley, dtype: object

# %%
test_df["Alley"].describe()
# Out:
# count      107
# unique       2
# top       Grvl
# freq        70
# Name: Alley, dtype: object

# %% [markdown]
# 可以看出：
# 1. 大部分数据都是空值
# 2. 建议删除掉该数据

# %%
train_df=train_df.drop(["Alley"], axis=1)
test_df=test_df.drop(["Alley"], axis=1)
train_df.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea LotShape LandContour  \
# 0   1          60         0         65.0     8450      Reg         Lvl
# 1   2          20         0         80.0     9600      Reg         Lvl
# 2   3          60         0         68.0    11250      IR1         Lvl
# 3   4          70         0         60.0     9550      IR1         Lvl
# 4   5          60         0         84.0    14260      IR1         Lvl
# 5   6          50         0         85.0    14115      IR1         Lvl
# 6   7          20         0         75.0    10084      Reg         Lvl
# 7   8          60         0          NaN    10382      IR1         Lvl
# 8   9          50         1         51.0     6120      Reg         Lvl
# 9  10         190         0         50.0     7420      Reg         Lvl
#
#   Utilities LotConfig LandSlope          ...          PoolQC  Fence  \
# 0    AllPub    Inside       Gtl          ...             NaN    NaN
# ...

# %% [markdown]
# ## 07-分析LotShape
# General shape of property

# %%
train_df["LotShape"].describe()
# Out:
# count     1460
# unique       4
# top        Reg
# freq       925
# Name: LotShape, dtype: object

# %%
test_df["LotShape"].describe()
# Out:
# count     1459
# unique       4
# top        Reg
# freq       934
# Name: LotShape, dtype: object

# %% [markdown]
# 可以看出：
# 1. 文本型取值
# 2. 训练数据和测试数据都没有空值
# 3. 取值只有4个
# 4. 数据的分布情况也很一致
# 5. 转化为顺序值

# %%
train_df["LotShape"].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
test_df["LotShape"].value_counts()
# Out:
# Reg    934
# IR1    484
# IR2     35
# IR3      6
# Name: LotShape, dtype: int64

# %%
g_lotshape=sns.FacetGrid(train_df, col="LotShape")
g_lotshape.map(plt.hist, "SalePrice")

# %%
train_df["LotShape"]=train_df["LotShape"].map({"Reg":0, "IR1":1, "IR2":2, "IR3":3}).astype(int)
test_df["LotShape"]=test_df["LotShape"].map({"Reg":0, "IR1":1, "IR2":2, "IR3":3}).astype(int)
train_df.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  LotShape LandContour  \
# 0   1          60         0         65.0     8450         0         Lvl
# 1   2          20         0         80.0     9600         0         Lvl
# 2   3          60         0         68.0    11250         1         Lvl
# 3   4          70         0         60.0     9550         1         Lvl
# 4   5          60         0         84.0    14260         1         Lvl
# 5   6          50         0         85.0    14115         1         Lvl
# 6   7          20         0         75.0    10084         0         Lvl
# 7   8          60         0          NaN    10382         1         Lvl
# 8   9          50         1         51.0     6120         0         Lvl
# 9  10         190         0         50.0     7420         0         Lvl
#
#   Utilities LotConfig LandSlope          ...          PoolQC  Fence  \
# 0    AllPub    Inside       Gtl          ...             NaN    NaN
# ...

# %% [markdown]
# ## 08-分析LandContour
# Flatness of the property

# %%
train_df["LandContour"].describe()
# Out:
# count     1460
# unique       4
# top        Lvl
# freq      1311
# Name: LandContour, dtype: object

# %%
test_df["LandContour"].describe()
# Out:
# count     1459
# unique       4
# top        Lvl
# freq      1311
# Name: LandContour, dtype: object

# %% [markdown]
# 可以看出：
# 1. 训练和测试数据都不为空
# 2. 文本型
# 3. 4个取值
# 4. 转化为顺序值
# 5. Lv1占据绝大多数
# 6. 除了顺序值，考虑只分为两类：Lv1和其他

# %%
train_df["LandContour"].value_counts()
# Out:
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64

# %%
test_df["LandContour"].value_counts()
# Out:
# Lvl    1311
# HLS      70
# Bnk      54
# Low      24
# Name: LandContour, dtype: int64

# %%
g_landcontour=sns.FacetGrid(train_df, col="LandContour")
g_landcontour.map(plt.hist, "SalePrice")

# %%
train_df["LandContour"]=train_df["LandContour"].map({"Lvl":0, "HLS":1, "Bnk":2, "Low":3}).astype(int)
test_df["LandContour"]=test_df["LandContour"].map({"Lvl":0, "HLS":1, "Bnk":2, "Low":3}).astype(int)
train_df.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# 0   1          60         0         65.0     8450         0            0
# 1   2          20         0         80.0     9600         0            0
# 2   3          60         0         68.0    11250         1            0
# 3   4          70         0         60.0     9550         1            0
# 4   5          60         0         84.0    14260         1            0
# 5   6          50         0         85.0    14115         1            0
# 6   7          20         0         75.0    10084         0            0
# 7   8          60         0          NaN    10382         1            0
# 8   9          50         1         51.0     6120         0            0
# 9  10         190         0         50.0     7420         0            0
#
#   Utilities LotConfig LandSlope          ...          PoolQC  Fence  \
# 0    AllPub    Inside       Gtl          ...             NaN    NaN
# ...

# %% [markdown]
# ## 09-分析Utilities
# Type of utilities available

# %%
train_df["Utilities"].describe()
# Out:
# count       1460
# unique         2
# top       AllPub
# freq        1459
# Name: Utilities, dtype: object

# %%
test_df["Utilities"].describe()
# Out:
# count       1457
# unique         1
# top       AllPub
# freq        1457
# Name: Utilities, dtype: object

# %% [markdown]
# 可以看出：
# 1. 训练数据没有空值
# 2. 测试数据有2个空值
# 3. 取值比较集中
# 4. 大部分的数据都一样，可以删除

# %%
train_df["Utilities"].value_counts()
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
test_df["Utilities"].value_counts()
# Out:
# AllPub    1457
# Name: Utilities, dtype: int64

# %%
train_df=train_df.drop(["Utilities"], axis=1)
test_df=test_df.drop(["Utilities"], axis=1)
train_df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# 0   1          60         0         65.0     8450         0            0
# 1   2          20         0         80.0     9600         0            0
# 2   3          60         0         68.0    11250         1            0
# 3   4          70         0         60.0     9550         1            0
# 4   5          60         0         84.0    14260         1            0
#
#   LotConfig LandSlope Neighborhood          ...          PoolQC Fence  \
# 0    Inside       Gtl      CollgCr          ...             NaN   NaN
# 1       FR2       Gtl      Veenker          ...             NaN   NaN
# 2    Inside       Gtl      CollgCr          ...             NaN   NaN
# 3    Corner       Gtl      Crawfor          ...             NaN   NaN
# 4       FR2       Gtl      NoRidge          ...             NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice  \
# ...

# %% [markdown]
# ## 10-分析LotConfig
# Lot configuration

# %%
train_df["LotConfig"].describe()
# Out:
# count       1460
# unique         5
# top       Inside
# freq        1052
# Name: LotConfig, dtype: object

# %%
test_df["LotConfig"].describe()
# Out:
# count       1459
# unique         5
# top       Inside
# freq        1081
# Name: LotConfig, dtype: object

# %%
train_df["LotConfig"].value_counts()
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64

# %%
test_df["LotConfig"].value_counts()
# Out:
# Inside     1081
# Corner      248
# CulDSac      82
# FR2          38
# FR3          10
# Name: LotConfig, dtype: int64

# %%
g_lotconfig=sns.FacetGrid(train_df, col="LotConfig")
g_lotconfig.map(plt.hist, "SalePrice")

# %% [markdown]
# 可以看出：
# 1. 文本型
# 2. 取值5个
# 3. 训练和测试数据都不为空
# 4. 训练和测试数据分布相似
# 5. 转化为顺序值

# %%
combine=[train_df, test_df]

for dataset in combine:
    dataset["LotConfig"]=dataset["LotConfig"].map({"Inside":0, "Corner":1, "CulDSac":2, "FR2":3, "FR3":4}).astype(int)
train_df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# 0   1          60         0         65.0     8450         0            0
# 1   2          20         0         80.0     9600         0            0
# 2   3          60         0         68.0    11250         1            0
# 3   4          70         0         60.0     9550         1            0
# 4   5          60         0         84.0    14260         1            0
#
#    LotConfig LandSlope Neighborhood          ...          PoolQC Fence  \
# 0          0       Gtl      CollgCr          ...             NaN   NaN
# 1          3       Gtl      Veenker          ...             NaN   NaN
# 2          0       Gtl      CollgCr          ...             NaN   NaN
# 3          1       Gtl      Crawfor          ...             NaN   NaN
# 4          3       Gtl      NoRidge          ...             NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice  \
# ...

# %% [markdown]
# ## 11-分析LandSlope
# Slope of property

# %%
train_df["LandSlope"].describe()
# Out:
# count     1460
# unique       3
# top        Gtl
# freq      1382
# Name: LandSlope, dtype: object

# %%
test_df["LandSlope"].describe()
# Out:
# count     1459
# unique       3
# top        Gtl
# freq      1396
# Name: LandSlope, dtype: object

# %%
train_df["LandSlope"].value_counts()
# Out:
# Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64

# %%
test_df["LandSlope"].value_counts()
# Out:
# Gtl    1396
# Mod      60
# Sev       3
# Name: LandSlope, dtype: int64

# %% [markdown]
# 可以看出：
# 1. 文本型
# 2. 训练和测试都没有空值
# 3. 取值3个
# 4. Gtl占据绝大多数
# 5. 要么转化为顺序值：3种
# 6. 要么分为两种：Gtl和其他

# %%
g_landslope=sns.FacetGrid(train_df, col="LandSlope")
g_landslope.map(plt.hist, "SalePrice")

# %%
combine=[train_df, test_df]

for dataset in combine:
    dataset["LandSlope"]=dataset["LandSlope"].map({"Gtl":0, "Mod":1, "Sev":2}).astype(int)
train_df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# 0   1          60         0         65.0     8450         0            0
# 1   2          20         0         80.0     9600         0            0
# 2   3          60         0         68.0    11250         1            0
# 3   4          70         0         60.0     9550         1            0
# 4   5          60         0         84.0    14260         1            0
#
#    LotConfig  LandSlope Neighborhood          ...          PoolQC Fence  \
# 0          0          0      CollgCr          ...             NaN   NaN
# 1          3          0      Veenker          ...             NaN   NaN
# 2          0          0      CollgCr          ...             NaN   NaN
# 3          1          0      Crawfor          ...             NaN   NaN
# 4          3          0      NoRidge          ...             NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice  \
# ...

# %% [markdown]
# ## 12-分析Neighborhood
# Physical locations within Ames city limits

# %%
train_df["Neighborhood"].describe()
# Out:
# count      1460
# unique       25
# top       NAmes
# freq        225
# Name: Neighborhood, dtype: object

# %%
test_df["Neighborhood"].describe()
# Out:
# count      1459
# unique       25
# top       NAmes
# freq        218
# Name: Neighborhood, dtype: object

# %%
train_df["Neighborhood"].value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
test_df["Neighborhood"].value_counts()
# Out:
# NAmes      218
# OldTown    126
# CollgCr    117
# Somerst     96
# Edwards     94
# NridgHt     89
# Gilbert     86
# Sawyer      77
# SawyerW     66
# Mitchel     65
# NWAmes      58
# IDOTRR      56
# Crawfor     52
# BrkSide     50
# Timber      34
# NoRidge     30
# StoneBr     26
# SWISU       23
# MeadowV     20
# ClearCr     16
# NPkVill     14
# BrDale      14
# Veenker     13
# Blmngtn     11
# Blueste      8
# Name: Neighborhood, dtype: int64

# %% [markdown]
# 可以看出：
# 1. 数据完整
# 2. 文本型
# 3. 25个取值
# 4. 转化为顺序值

# %%
Neighborhood_map={v:i for i,v in enumerate(list(set(train_df["Neighborhood"].values)))}
Neighborhood_map
# Out:
# {'Blmngtn': 19,
#  'Blueste': 18,
#  'BrDale': 22,
#  'BrkSide': 24,
#  'ClearCr': 12,
#  'CollgCr': 17,
#  'Crawfor': 13,
#  'Edwards': 6,
#  'Gilbert': 2,
#  'IDOTRR': 14,
#  'MeadowV': 0,
#  'Mitchel': 16,
#  'NAmes': 11,
#  'NPkVill': 20,
#  'NWAmes': 8,
#  'NoRidge': 9,
#  'NridgHt': 15,
#  'OldTown': 4,
#  'SWISU': 10,
#  'Sawyer': 3,
#  'SawyerW': 21,
#  'Somerst': 1,
#  'StoneBr': 23,
#  'Timber': 7,
#  'Veenker': 5}

# %%
combine=[train_df, test_df]
for dataset in combine:
    for k,v in Neighborhood_map.items():
        dataset.loc[dataset["Neighborhood"]==k, "Neighborhood"]=v
    dataset["Neighborhood"].astype(int)
train_df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# 0   1          60         0         65.0     8450         0            0
# 1   2          20         0         80.0     9600         0            0
# 2   3          60         0         68.0    11250         1            0
# 3   4          70         0         60.0     9550         1            0
# 4   5          60         0         84.0    14260         1            0
#
#    LotConfig  LandSlope Neighborhood          ...          PoolQC Fence  \
# 0          0          0           17          ...             NaN   NaN
# 1          3          0            5          ...             NaN   NaN
# 2          0          0           17          ...             NaN   NaN
# 3          1          0           13          ...             NaN   NaN
# 4          3          0            9          ...             NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice  \
# ...

# %% [markdown]
# ## 13-分析Condition1
# Proximity to main road or railroad

# %%
train_df["Condition1"].describe()
# Out:
# count     1460
# unique       9
# top       Norm
# freq      1260
# Name: Condition1, dtype: object

# %%
test_df["Condition1"].describe()
# Out:
# count     1459
# unique       9
# top       Norm
# freq      1251
# Name: Condition1, dtype: object

# %%
train_df["Condition1"].value_counts()
# Out:
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64

# %%
test_df["Condition1"].value_counts()
# Out:
# Norm      1251
# Feedr       83
# Artery      44
# RRAn        24
# PosN        20
# RRAe        17
# PosA        12
# RRNn         4
# RRNe         4
# Name: Condition1, dtype: int64

# %%
train_df[["Condition1", "SalePrice"]].groupby(["Condition1"], as_index=False).mean().sort_values(by="SalePrice", ascending=True)
# Out:
#   Condition1      SalePrice
# 0     Artery  135091.666667
# 5       RRAe  138400.000000
# 1      Feedr  142475.481481
# 6       RRAn  184396.615385
# 2       Norm  184495.492063
# 7       RRNe  190750.000000
# 8       RRNn  212400.000000
# 4       PosN  215184.210526
# 3       PosA  225875.000000

# %% [markdown]
# 可以看出：
# 1. 都不为空
# 2. 文本型
# 3. 9个取值
# 4. 转化为顺序值
# 5. Norm占据多数，考虑减少分类

# %%
Condition1_map={v:ii for ii,v in enumerate(list(set(train_df["Condition1"].values)))}
combine=[train_df, test_df]
for dataset in combine:
    for k,v in Condition1_map.items():
        dataset.loc[dataset["Condition1"]==k, "Condition1"]=v
    dataset["Condition1"].astype(int)
train_df["Condition1"].head()
# Out:
# 0    4
# 1    2
# 2    4
# 3    4
# 4    4
# Name: Condition1, dtype: object

# %% [markdown]
# ## 14-分析Condition2
# Proximity to main road or railroad (if a second is present)

# %%
train_df["Condition2"].describe()
# Out:
# count     1460
# unique       8
# top       Norm
# freq      1445
# Name: Condition2, dtype: object

# %%
test_df["Condition2"].describe()
# Out:
# count     1459
# unique       5
# top       Norm
# freq      1444
# Name: Condition2, dtype: object

# %%
train_df["Condition2"].value_counts()
# Out:
# Norm      1445
# Feedr        6
# RRNn         2
# PosN         2
# Artery       2
# PosA         1
# RRAn         1
# RRAe         1
# Name: Condition2, dtype: int64

# %%
test_df["Condition2"].value_counts()
# Out:
# Norm      1444
# Feedr        7
# PosA         3
# Artery       3
# PosN         2
# Name: Condition2, dtype: int64

# %% [markdown]
# 可以看出：
# 1. 都不为空
# 2. 文本型
# 3. 8个取值
# 4. 主要集中在Norm，与Condition1的分布类似
# 5. 先转化顺序值看看
# 6. 最好能找出这两者与售价之间的关系

# %%
Condition2_maps={v:ii for ii,v in enumerate(list(set(train_df["Condition2"].values)))}
combine=[train_df, test_df]
for dataset in combine:
    for k,v in Condition2_maps.items():
        dataset.loc[dataset["Condition2"]==k, "Condition2"]=v
    dataset["Condition2"].astype(int)
train_df["Condition2"].head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: Condition2, dtype: object

# %%
# Condition1 和 Condition2的取值是一样的吗？
for k2 in Condition2_maps:
    if k2 not in Condition1_map:
        print("not in")
        break
print("Condition2 keys are all in Condition1")
# Out:
# Condition2 keys are all in Condition1

# %% [markdown]
# ### Condition1 和 Condition2 之间的取值是一致的，因此，可以使用同一个map，映射到顺序值，同时考虑，两者是否能够组合出新的特征

# %%
g_Condition2=sns.FacetGrid(train_df, row="Condition1", col="Condition2")
g_Condition2.map(plt.hist, "SalePrice")

# %% [markdown]
# ## 15-分析BldgType
# Type of dwelling

# %%
train_df["BldgType"].describe()
# Out:
# count     1460
# unique       5
# top       1Fam
# freq      1220
# Name: BldgType, dtype: object

# %%
test_df["BldgType"].describe()
# Out:
# count     1459
# unique       5
# top       1Fam
# freq      1205
# Name: BldgType, dtype: object

# %%
train_df["BldgType"].value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
test_df["BldgType"].value_counts()
# Out:
# 1Fam      1205
# TwnhsE     113
# Duplex      57
# Twnhs       53
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
g_BldgType=sns.FacetGrid(train_df, col="BldgType")
g_BldgType.map(plt.hist, "SalePrice")

# %% [markdown]
# ## 通用方法
# 将数据集中指定列（文本型），转化为顺序值

# %%
def map_text_to_ints(dataset, col_name):
    col_maps={v:ii for ii,v in enumerate(list(set(dataset[col_name].values)))}
    for k,v in col_maps.items():
        dataset.loc[dataset[col_name]==k, col_name]=v
    dataset[col_name].astype(int)
    return dataset

# %% [markdown]
# 可以看出：
# 1. 都不为空
# 2. 文本型
# 3. 集中在1Fam
# 4. 转化为顺序值

# %%
combine=[train_df, test_df]
for dataset in combine:
    dataset=map_text_to_ints(dataset, "BldgType")
train_df["BldgType"].head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: BldgType, dtype: object

# %% [markdown]
# ## 通用方法
# 查看训练数据和测试数据指定列

# %%
def look_data(col_name):
    print("------------- train of "+ col_name+" -----------------------")
    print(train_df[col_name].head())
    print("\n")
    print(train_df[col_name].describe())
    print("\n")
    print(train_df[col_name].value_counts())
    print("------------- test of "+ col_name+" -----------------------")
    print(test_df[col_name].head())
    print("\n")
    print(test_df[col_name].describe())
    print("\n")
    print(test_df[col_name].value_counts())

# %% [markdown]
# ## 16-分析HouseStyle
# Style of dwelling

# %%
train_df["HouseStyle"].describe()
# Out:
# count       1460
# unique         8
# top       1Story
# freq         726
# Name: HouseStyle, dtype: object

# %%
look_data("HouseStyle")
# Out:
# ------------- train of HouseStyle -----------------------
# 0    2Story
# 1    1Story
# 2    2Story
# 3    2Story
# 4    2Story
# Name: HouseStyle, dtype: object
#
#
# count       1460
# unique         8
# top       1Story
# freq         726
# Name: HouseStyle, dtype: object
#
#
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64
# ------------- test of HouseStyle -----------------------
# 0    1Story
# 1    1Story
# 2    2Story
# 3    2Story
# 4    1Story
# Name: HouseStyle, dtype: object
#
#
# count       1459
# unique         7
# top       1Story
# freq         745
# Name: HouseStyle, dtype: object
#
#
# 1Story    745
# 2Story    427
# 1.5Fin    160
# SLvl       63
# SFoyer     46
# 2.5Unf     13
# 1.5Unf      5
# Name: HouseStyle, dtype: int64

# %% [markdown]
# 可以看出：
# 1. 都不为空
# 2. 文本型
# 3. 8个取值
# 4. 转化为顺序值

# %%
combine=[train_df, test_df]
for dataset in combine:
    dataset=map_text_to_ints(dataset,"HouseStyle")
look_data("HouseStyle")
# Out:
# ------------- train of HouseStyle -----------------------
# 0    4
# 1    2
# 2    4
# 3    4
# 4    4
# Name: HouseStyle, dtype: object
#
#
# count     1460
# unique       8
# top          2
# freq       726
# Name: HouseStyle, dtype: int64
#
#
# 2    726
# 4    445
# 7    154
# 5     65
# 3     37
# 0     14
# 1     11
# 6      8
# Name: HouseStyle, dtype: int64
# ------------- test of HouseStyle -----------------------
# 0    2
# 1    2
# 2    4
# 3    4
# 4    2
# Name: HouseStyle, dtype: object
#
#
# count     1459
# unique       7
# top          2
# freq       745
# Name: HouseStyle, dtype: int64
#
#
# 2    745
# 4    427
# 6    160
# 5     63
# 3     46
# 1     13
# 0      5
# Name: HouseStyle, dtype: int64

# %% [markdown]
# ## 17-分析OverallQual
#  Overall material and finish quality

# %%
train_df["OverallQual"].describe()
# Out:
# count    1460.000000
# mean        6.099315
# std         1.382997
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: OverallQual, dtype: float64

# %%
train_df["OverallQual"].head(10)
# Out:
# 0    7
# 1    6
# 2    7
# 3    7
# 4    8
# 5    5
# 6    8
# 7    7
# 8    7
# 9    5
# Name: OverallQual, dtype: int64

# %%
look_data("OverallQual")
# Out:
# ------------- train of OverallQual -----------------------
# 0    7
# 1    6
# 2    7
# 3    7
# 4    8
# Name: OverallQual, dtype: int64
#
#
# count    1460.000000
# mean        6.099315
# std         1.382997
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: OverallQual, dtype: float64
#
#
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64
# ------------- test of OverallQual -----------------------
# 0    5
# 1    6
# 2    5
# 3    6
# 4    8
# Name: OverallQual, dtype: int64
#
#
# count    1459.000000
# mean        6.078821
# std         1.436812
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: OverallQual, dtype: float64
#
#
# 5     428
# 6     357
# 7     281
# 8     174
# 4     110
# 9      64
# 3      20
# 10     13
# 2      10
# ...

# %% [markdown]
# 可以看出：
# 1. 没有空值
# 2. 1-10的数值
# 3. 不用处理

# %%
g_OverallQual=sns.FacetGrid(train_df, row="OverallQual")
g_OverallQual.map(plt.hist, "SalePrice")

# %% [markdown]
# ## 18-分析OverallCond
#  Overall condition rating

# %%
train_df["OverallCond"].describe()
# Out:
# count    1460.000000
# mean        5.575342
# std         1.112799
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         6.000000
# max         9.000000
# Name: OverallCond, dtype: float64

# %%
look_data("OverallCond")
# Out:
# ------------- train of OverallCond -----------------------
# 0    5
# 1    8
# 2    5
# 3    5
# 4    5
# Name: OverallCond, dtype: int64
#
#
# count    1460.000000
# mean        5.575342
# std         1.112799
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         6.000000
# max         9.000000
# Name: OverallCond, dtype: float64
#
#
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64
# ------------- test of OverallCond -----------------------
# 0    6
# 1    6
# 2    5
# 3    6
# 4    5
# Name: OverallCond, dtype: int64
#
#
# count    1459.000000
# mean        5.553804
# std         1.113740
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         6.000000
# max         9.000000
# Name: OverallCond, dtype: float64
#
#
# 5    824
# 6    279
# 7    185
# 8     72
# 4     44
# 3     25
# 9     19
# 1      6
# 2      5
# ...

# %% [markdown]
# 可以看出：
# 1. 都不为空
# 2. 不需要处理

# %% [markdown]
# ## 19-分析YearBuilt
#  Original construction date

# %%
train_df["YearBuilt"].describe()
# Out:
# count    1460.000000
# mean     1971.267808
# std        30.202904
# min      1872.000000
# 25%      1954.000000
# 50%      1973.000000
# 75%      2000.000000
# max      2010.000000
# Name: YearBuilt, dtype: float64

# %%
look_data("YearBuilt")
# Out:
# ------------- train of YearBuilt -----------------------
# 0    2003
# 1    1976
# 2    2001
# 3    1915
# 4    2000
# Name: YearBuilt, dtype: int64
#
#
# count    1460.000000
# mean     1971.267808
# std        30.202904
# min      1872.000000
# 25%      1954.000000
# 50%      1973.000000
# 75%      2000.000000
# max      2010.000000
# Name: YearBuilt, dtype: float64
#
#
# 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
# 1976    33
# 1977    32
# 1920    30
# 1959    26
# 1999    25
# 1998    25
# 1958    24
# 1965    24
# 1970    24
# 1954    24
# 2000    24
# 2002    23
# 2008    23
# 1972    23
# 1968    22
# 1971    22
# 1950    20
# 2001    20
# 1957    20
# 1962    19
# 1994    19
# 1966    18
# 2009    18
# 1995    18
# 1940    18
#         ..
# 1986     5
# 1952     5
# 1880     4
# 1929     4
# 1932     4
# 1938     4
# 1983     4
# 1927     3
# 1919     3
# 1934     3
# 1989     3
# 1987     3
# 1912     3
# 1885     2
# 1892     2
# 1890     2
# ...

# %% [markdown]
# 可以看出：
# 1. 都不为空
# 2. 数值型
# 3. 可以根据年代，进行分段
# 4. 最老的是1872年
# 5. 最新的是2010年
